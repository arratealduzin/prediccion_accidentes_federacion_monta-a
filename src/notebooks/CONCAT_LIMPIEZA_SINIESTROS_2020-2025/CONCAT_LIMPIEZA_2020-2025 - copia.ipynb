# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Accidentes 2024

# %%
df_arrate = pd.read_csv("/Users/Arrate/Desktop/2024-Partes accidentes.xlsx - 2024-ListadoPartes.csv")
df_arrate
# Out:
#            NIF    Nombre Apellido1              Apellido2 FechaParteAccidente  \
# 0    05277296S     MARIA     NAZAR  ENRIQUEZ DE SALAMANCA         1/1/24 0:00
# 1    50775542Y     PABLO  SAN JOSE                   PEÑA        1/1/24 14:00
# 2    11851622K     PAULA   ARQUERO              CONTRERAS        1/2/24 17:00
# 3    50208024J    MIGUEL     PEREZ               PANIAGUA         1/4/24 0:00
# 4    09141804V    VICTOR  MORALEDA                ALVAREZ        1/4/24 19:30
# ..         ...       ...       ...                    ...                 ...
# 626  50869317X     DIEGO  MARTINEZ                CARULLA      12/24/24 13:00
# 627  53766505A    JAVIER     LOPEZ                 GARCIA      12/26/24 14:15
# 628  53498177Q  VIRGINIA   SANCHEZ               SALMERON      12/28/24 15:00
# 629  70075086C     BORJA   VICENTE                   ZAZO      12/29/24 17:00
# 630  71736397H    MARCOS  GONZALEZ              FERNANDEZ      12/30/24 13:10
#
#      FechaAltaParte     Codigo  \
# 0      1/2/24 12:04  745025061
# 1      1/2/24 10:48  745024991
# 2      1/18/24 9:27  745038371
# 3     1/15/24 16:09  745034561
# 4      1/4/24 23:32  745025901
# ..              ...        ...
# 626  12/30/24 11:34  745371711
# 627  12/26/24 17:59  745371250
# 628  12/29/24 10:18  745371881
# 629    3/2/25 17:55  745372611
# 630   12/31/24 9:34  745372681
#
#                                       DescripcionParte              Actividad  \
# 0                                      Caida esquiando           Esquí Alpino
# 1    Montando en mtb, mi pie salio del pedal y se g...                    BTT
# 2    Caída al ir andando con la bicicleta y tropeza...                    BTT
# 3             Caída de manos. Golpe en la mano derecha   Carreras por montaña
# 4    Accidente en rocódromo,haciendo dry tooling, c...              Rocódromo
# ..                                                 ...                    ...
# 626  Escalando noto un ruido muy fuerte en un dedo ...              Rocódromo
# 627  Practicando escalada deportiva, se ha desprend...    Escalada en escuela
# 628          Tropiezo torciéndome el tobillo izquierdo   Carreras por montaña
# 629                                 Luxación de hombro  Escalada alta montaña
# 630  Caída escalando en escuela de escalada de Fuen...    Escalada en escuela
#
#                                                  Lugar  ... ActividadPersonal  \
# 0                                       Baqueira Beret  ...              True
# 1                                             El Pardo  ...             False
# 2    Carretera de la republica - Dehesas de Cercedilla  ...              True
# 3                                           La pedriza  ...             False
# 4                                 Rocódromo indoorwall  ...             False
# ..                                                 ...  ...               ...
# 626                                     sharmaclimbing  ...             False
# 627                                    Torrent d Avall  ...              True
# 628                                            Abantos  ...             False
# 629                                             Murcia  ...              True
# 630                                        Fuentidueña  ...              True
#
#     ActividadOrganizada  Festivo NResponsables TamañoGrupo  \
# 0                 False    False             0           0
# 1                 False    False             1           0
# 2                 False    False             0           0
# 3                 False    False             1           1
# 4                 False    False             1           9
# ..                  ...      ...           ...         ...
# 626               False    False             1           1
# 627               False    False             0           3
# 628               False    False             2           2
# 629               False    False             0           0
# 630               False    False             3           3
#
#      CentroHospitalizacion  DescripcionGrado    Pais      Provincia  \
# 0                      NaN              Leve  España         LLEIDA
# 1                      NaN               NaN  España         MADRID
# 2                      NaN              Leve  España         MADRID
# 3                      NaN              Leve  España         MADRID
# 4                      NaN               NaN  España         MADRID
# ..                     ...               ...     ...            ...
# 626                    NaN              Leve  España         MADRID
# 627                    NaN             Grave  España  ILLES BALEARS
# 628                    NaN              Leve  España         MADRID
# 629                  Cieza              Leve  España         MADRID
# 630                    NaN             Grave  España        SEGOVIA
#
#                            TipoAccidente
# 0       Tropiezos (caída al mismo nivel)
# 1                  Otro: Golpe en el pie
# 2       Tropiezos (caída al mismo nivel)
# 3                     Colisión con rocas
# 4    Otro: Corte con el filo del crampón
# ..                                   ...
# 626                    Problemas físicos
# 627                   Colisión con rocas
# 628     Tropiezos (caída al mismo nivel)
# 629                    Problemas físicos
# 630                    Caída en vertical
#
# [631 rows x 26 columns]

# %%
df_arrate["NIF"] = df_arrate["NIF"].astype(str).str.strip().str.upper()

# %%
df_arrate["NIF"].value_counts(dropna=False)
# Out:
# NIF
# 70071185Y    3
# 05714595S    3
# 51446295X    3
# 78889989N    2
# 50942493T    2
#             ..
# 50869317X    1
# 53766505A    1
# 53498177Q    1
# 70075086C    1
# 05277296S    1
# Name: count, Length: 589, dtype: int64

# %%
df_arrate.isnull().sum()
# Out:
# NIF                        0
# Nombre                     0
# Apellido1                  0
# Apellido2                  1
# FechaParteAccidente        0
# FechaAltaParte             0
# Codigo                     0
# DescripcionParte           0
# Actividad                  0
# Lugar                      0
# FechaRecepcion             0
# CentroUrgencias          374
# Helicoptero              631
# MacizoMontañoso            3
# NombreParaje               3
# Entrenamiento              0
# ActividadPersonal          0
# ActividadOrganizada        0
# Festivo                    0
# NResponsables              0
# TamañoGrupo                0
# CentroHospitalizacion    577
# DescripcionGrado          42
# Pais                       0
# Provincia                  0
# TipoAccidente              0
# dtype: int64

# %%
df_arrate['accidentes_2024'] = df_arrate['DescripcionParte'].notna()

# %%
df_arrate.columns
# Out:
# Index(['NIF', 'Nombre', 'Apellido1', 'Apellido2', 'FechaParteAccidente',
#        'FechaAltaParte', 'Codigo', 'DescripcionParte', 'Actividad', 'Lugar',
#        'FechaRecepcion', 'CentroUrgencias', 'Helicoptero', 'MacizoMontañoso',
#        'NombreParaje', 'Entrenamiento', 'ActividadPersonal',
#        'ActividadOrganizada', 'Festivo', 'NResponsables', 'TamañoGrupo',
#        'CentroHospitalizacion', 'DescripcionGrado', 'Pais', 'Provincia',
#        'TipoAccidente', 'accidentes_2024'],
#       dtype='object')

# %%
df_arrate["accidentes_2024"]
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 626    True
# 627    True
# 628    True
# 629    True
# 630    True
# Name: accidentes_2024, Length: 631, dtype: bool

# %%
df_arrate[df_arrate.duplicated(subset=['NIF'], keep=False)].sort_values(by='NIF')
# Out:
#            NIF     Nombre Apellido1         Apellido2 FechaParteAccidente  \
# 359  00398302B  JOSE LUIS    GARCIA         FERNANDEZ        7/6/24 12:15
# 196  00398302B  JOSE LUIS    GARCIA         FERNANDEZ       4/11/24 19:00
# 350  00683428Y    YOLANDA     RUEDA           TANARRO       6/30/24 17:00
# 545  00683428Y    YOLANDA     RUEDA           TANARRO        11/3/24 0:00
# 479  02282680E       JUAN    CAMPOS            ORTEGA       9/27/24 21:00
# ..         ...        ...       ...               ...                 ...
# 405  76249980N  JOSE RAUL    CALERO           ALVAREZ       7/31/24 20:00
# 212  78889989N      MIKEL     ANTIA  ALVAREZ-ELICEGUI       4/16/24 19:45
# 93   78889989N      MIKEL     ANTIA  ALVAREZ-ELICEGUI       2/22/24 20:00
# 316  X9133548H     MARIAN     PAVEL                 .       6/15/24 10:30
# 567  X9133548H     MARIAN     PAVEL                 .      11/17/24 14:30
#
#      FechaAltaParte     Codigo  \
# 359    7/12/24 9:31  745229101
# 196   4/14/24 11:50  745140301
# 350    7/2/24 17:12  745225231
# 545  11/18/24 12:49  745329981
# 479    9/28/24 9:56  745271951
# ..              ...        ...
# 405    8/5/24 11:16  745242021
# 212    4/17/24 8:43  745144331
# 93    2/26/24 10:22  745084631
# 316   6/17/24 20:12  745214911
# 567  11/18/24 17:11  745330391
#
#                                       DescripcionParte  \
# 359  Según información redundante de la Organizació...
# 196  Tropezón y caída bajando por un sendero,fuerte...
# 350  **** Resbalón y caida.apoyando mano derecha --...
# 545  Subiendo por un camino resbale y caí haciéndom...
# 479     Dolor inteso en gemelo izquierdo con chasquido
# ..                                                 ...
# 405  Estábamos haciendo la ruta de la sima Berger e...
# 212  entrenando en el rocódromo me siento patada en...
# 93   *** Torcedura con chasquido en dedo anular izq...
# 316                     Esguince tobillo al pisar mal.
# 567                Lesión dedo corazón mano izquierda.
#
#                                      Actividad                       Lugar  \
# 359                       Carreras por montaña                     Somiedo
# 196                       Carreras por montaña     Fonda Real, Navacerrada
# 350  Montañismo/Progresión por terreno abrupto                    Pirineos
# 545  Montañismo/Progresión por terreno abrupto                    Pirineos
# 479                       Carreras por montaña                Torrelodones
# ..                                         ...                         ...
# 405                               Espeleología                      Berger
# 212                                  Rocódromo  San Sebastian de los Reyes
# 93                                   Rocódromo                      Madrid
# 316                                  Rocódromo                       Roc30
# 567                        Escalada en escuela                      cuenca
#
#      ... ActividadOrganizada Festivo  NResponsables TamañoGrupo  \
# 359  ...                True   False              0           0
# 196  ...               False   False              1           0
# 350  ...                True   False              2          10
# 545  ...                True   False              2          10
# 479  ...               False   False              1           1
# ..   ...                 ...     ...            ...         ...
# 405  ...               False   False              1           4
# 212  ...               False   False              0           0
# 93   ...               False   False              1           0
# 316  ...               False   False              0           0
# 567  ...               False   False              1           2
#
#     CentroHospitalizacion  DescripcionGrado     Pais  Provincia  \
# 359                   NaN            Mortal   España   ASTURIAS
# 196                   NaN              Leve   España     MADRID
# 350                   NaN              Leve   España     MADRID
# 545                   NaN              Leve   España     MADRID
# 479                   NaN              Leve   España     MADRID
# ..                    ...               ...      ...        ...
# 405                   NaN              Leve  Francia          -
# 212                   NaN              Leve   España     MADRID
# 93                    NaN              Leve   España     MADRID
# 316                   NaN              Leve   España     MADRID
# 567                   NaN              Leve   España     CUENCA
#
#                         TipoAccidente  accidentes_2024
# 359                     Enriscamiento             True
# 196  Tropiezos (caída al mismo nivel)             True
# 350  Tropiezos (caída al mismo nivel)             True
# 545  Tropiezos (caída al mismo nivel)             True
# 479                 Problemas físicos             True
# ..                                ...              ...
# 405                 Problemas físicos             True
# 212                 Problemas físicos             True
# 93                  Problemas físicos             True
# 316  Tropiezos (caída al mismo nivel)             True
# 567                 Problemas físicos             True
#
# [81 rows x 27 columns]

# %%
df_arrate.drop_duplicates(subset=['NIF','Apellido1','Apellido2','FechaParteAccidente'], keep='first', inplace=True)

# %%
df_arrate[df_arrate.duplicated(subset=['NIF'], keep=False)].sort_values(by='NIF')
# Out:
#            NIF     Nombre Apellido1         Apellido2 FechaParteAccidente  \
# 196  00398302B  JOSE LUIS    GARCIA         FERNANDEZ       4/11/24 19:00
# 359  00398302B  JOSE LUIS    GARCIA         FERNANDEZ        7/6/24 12:15
# 545  00683428Y    YOLANDA     RUEDA           TANARRO        11/3/24 0:00
# 350  00683428Y    YOLANDA     RUEDA           TANARRO       6/30/24 17:00
# 11   02519616N    ANTONIO   DE ORBE          MENDIOLA        1/9/24 11:00
# ..         ...        ...       ...               ...                 ...
# 528  76249980N  JOSE RAUL    CALERO           ALVAREZ       10/20/24 0:00
# 93   78889989N      MIKEL     ANTIA  ALVAREZ-ELICEGUI       2/22/24 20:00
# 212  78889989N      MIKEL     ANTIA  ALVAREZ-ELICEGUI       4/16/24 19:45
# 316  X9133548H     MARIAN     PAVEL                 .       6/15/24 10:30
# 567  X9133548H     MARIAN     PAVEL                 .      11/17/24 14:30
#
#      FechaAltaParte     Codigo  \
# 196   4/14/24 11:50  745140301
# 359    7/12/24 9:31  745229101
# 545  11/18/24 12:49  745329981
# 350    7/2/24 17:12  745225231
# 11     1/9/24 17:45  745028401
# ..              ...        ...
# 528  10/20/24 16:05  745298311
# 93    2/26/24 10:22  745084631
# 212    4/17/24 8:43  745144331
# 316   6/17/24 20:12  745214911
# 567  11/18/24 17:11  745330391
#
#                                       DescripcionParte  \
# 196  Tropezón y caída bajando por un sendero,fuerte...
# 359  Según información redundante de la Organizació...
# 545  Subiendo por un camino resbale y caí haciéndom...
# 350  **** Resbalón y caida.apoyando mano derecha --...
# 11                                Torcedura de rodilla
# ..                                                 ...
# 528   Accidente escalando. Golpe fuerte en pie derecho
# 93   *** Torcedura con chasquido en dedo anular izq...
# 212  entrenando en el rocódromo me siento patada en...
# 316                     Esguince tobillo al pisar mal.
# 567                Lesión dedo corazón mano izquierda.
#
#                                      Actividad                       Lugar  \
# 196                       Carreras por montaña     Fonda Real, Navacerrada
# 359                       Carreras por montaña                     Somiedo
# 545  Montañismo/Progresión por terreno abrupto                    Pirineos
# 350  Montañismo/Progresión por terreno abrupto                    Pirineos
# 11                                  Senderismo                 Bustarviejo
# ..                                         ...                         ...
# 528                        Escalada en escuela                Torrelodones
# 93                                   Rocódromo                      Madrid
# 212                                  Rocódromo  San Sebastian de los Reyes
# 316                                  Rocódromo                       Roc30
# 567                        Escalada en escuela                      cuenca
#
#      ... ActividadOrganizada Festivo  NResponsables TamañoGrupo  \
# 196  ...               False   False              1           0
# 359  ...                True   False              0           0
# 545  ...                True   False              2          10
# 350  ...                True   False              2          10
# 11   ...               False   False              0           0
# ..   ...                 ...     ...            ...         ...
# 528  ...               False   False              1           2
# 93   ...               False   False              1           0
# 212  ...               False   False              0           0
# 316  ...               False   False              0           0
# 567  ...               False   False              1           2
#
#     CentroHospitalizacion  DescripcionGrado    Pais    Provincia  \
# 196                   NaN              Leve  España       MADRID
# 359                   NaN            Mortal  España     ASTURIAS
# 545                   NaN              Leve  España       MADRID
# 350                   NaN              Leve  España       MADRID
# 11                    NaN              Leve  España       MADRID
# ..                    ...               ...     ...          ...
# 528                   NaN              Leve  España  GUADALAJARA
# 93                    NaN              Leve  España       MADRID
# 212                   NaN              Leve  España       MADRID
# 316                   NaN              Leve  España       MADRID
# 567                   NaN              Leve  España       CUENCA
#
#                         TipoAccidente  accidentes_2024
# 196  Tropiezos (caída al mismo nivel)             True
# 359                     Enriscamiento             True
# 545  Tropiezos (caída al mismo nivel)             True
# 350  Tropiezos (caída al mismo nivel)             True
# 11   Tropiezos (caída al mismo nivel)             True
# ..                                ...              ...
# 528                 Caída en vertical             True
# 93                  Problemas físicos             True
# 212                 Problemas físicos             True
# 316  Tropiezos (caída al mismo nivel)             True
# 567                 Problemas físicos             True
#
# [67 rows x 27 columns]

# %% [markdown]
# # LICENCIAS 2024

# %%
import numpy as np
import pandas as pd

# %%
df_fer_2024_arrate = pd.read_csv("/Users/Arrate/Desktop/Licencias_2024y2025.xlsx - Licencias_2024.csv")
# Out:
# C:\Users\Arrate\AppData\Local\Temp\ipykernel_4428\635204347.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fer_2024_arrate = pd.read_csv("/Users/Arrate/Desktop/Licencias_2024y2025.xlsx - Licencias_2024.csv")

# %%
df_fer_2024_arrate
# Out:
#                 Nombre Apellido1  Apellido2 Sexo FechaNacimiento  \
# 0         MIGUEL ANGEL      ABAD       ABAD    H       1/26/1993
# 1             CRISTINA      ABAD     ARRANZ    M        3/8/1990
# 2                 LUNA      ABAD     CAMPOS    M       4/26/2013
# 3         JOSE ANTONIO      ABAD    CANDELA    H       7/30/1936
# 4      ESTEBAN EUSEBIO      ABAD  DE MIGUEL    H      12/16/1946
# ...                ...       ...        ...  ...             ...
# 18910            PILAR     ZURDO      GOMEZ    M       2/19/1979
# 18911          ANTONIO     ZURDO     MARTIN    H       9/24/1949
# 18912            DIEGO     ZURDO      PEREZ    H      12/30/1978
# 18913     LUIS ALFONSO    ZURITA   GONZALEZ    H       8/17/1982
# 18914     MARIA ISABEL     ZURRO     FRAILE    M       7/12/1962
#
#               PoblacionDomicilio DescripcionProvinciaDomicilio  \
# 0                    GUADALAJARA                   GUADALAJARA
# 1                     VALLADOLID                    VALLADOLID
# 2                         GETAFE                        MADRID
# 3                         MADRID                        MADRID
# 4                         MADRID                        MADRID
# ...                          ...                           ...
# 18910                 VALDEOLMOS                        MADRID
# 18911  S. SEBASTIAN DE LOS REYES                        MADRID
# 18912          ALCALA DE HENARES                        MADRID
# 18913                     Madrid                        MADRID
# 18914                     MADRID                        MADRID
#
#       CodigoPostalDomicilio  Unnamed: 8  Unnamed: 9  ...  NSocio  \
# 0                     19003         NaN         NaN  ...   77005
# 1                     47300         NaN         NaN  ...   71299
# 2                     28906         NaN         NaN  ...   73846
# 3                     28028         NaN         NaN  ...   58372
# 4                     28017         NaN         NaN  ...   56522
# ...                     ...         ...         ...  ...     ...
# 18910                 28130         NaN         NaN  ...   59252
# 18911                 28702         NaN         NaN  ...   38999
# 18912                 28804         NaN         NaN  ...   55899
# 18913                 28002         NaN         NaN  ...   69051
# 18914                 28035         NaN         NaN  ...   55184
#
#                                 DireccionDomicilio NIFFamiliar TipoTarjeta  \
# 0                         CALLE CONSTITUCIÓN 37 4D         NaN           D
# 1                  CARRETERA DE PESQUERA NUMERO 30         NaN           D
# 2      CALLE DE LA GIGANTA ANDANDONA 6 PORTAL 1 3C         NaN           P
# 3           AVENIDA BAVIERA NUMERO 12 PISO 6º, IZQ         NaN           P
# 4                 CALLE SERVANDO BATANERO NUMERO 1         NaN           D
# ...                                            ...         ...         ...
# 18910           Calle CAMINO DE SERRACINES Nº8 1ºC         NaN           P
# 18911               CALLE DAMASO ALONSO, 26 CHALET         NaN           D
# 18912                          Calle LUGO, 7 - 5ºA         NaN           P
# 18913                       Calle Clara del Rey 59         NaN           P
# 18914       C/ FEDERICO CARLOS SAINZ DE ROBLES, 23         NaN           D
#
#              Alta  Cuaderno19 Bloqueado envíos Unnamed: 34 Envío tarjeta  \
# 0            FORM          NO               NO         NaN            NO
# 1         SERVWEB          NO               NO         NaN            NO
# 2      INDIVIDUAL          SI               NO         NaN            NO
# 3      INDIVIDUAL          SI               NO         NaN            NO
# 4          ENLACE          NO               NO         NaN            NO
# ...           ...         ...              ...         ...           ...
# 18910     SERVWEB          NO               SI         NaN            NO
# 18911  INDIVIDUAL          SI               NO         NaN            NO
# 18912  INDIVIDUAL          SI               NO         NaN            NO
# 18913      ENLACE          NO               NO         NaN            SI
# 18914      REMESA          SI               NO         NaN            NO
#
#        Discapacidad
# 0                NO
# 1                NO
# 2                NO
# 3                NO
# 4                NO
# ...             ...
# 18910            NO
# 18911            NO
# 18912            NO
# 18913            NO
# 18914            NO
#
# [18915 rows x 37 columns]

# %%
df_fer_2024_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18915 entries, 0 to 18914
# Data columns (total 37 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nombre                         18915 non-null  object
#  1   Apellido1                      18915 non-null  object
#  2   Apellido2                      18896 non-null  object
#  3   Sexo                           18915 non-null  object
#  4   FechaNacimiento                18915 non-null  object
#  5   PoblacionDomicilio             18915 non-null  object
#  6   DescripcionProvinciaDomicilio  18915 non-null  object
#  7   CodigoPostalDomicilio          18915 non-null  object
#  8   Unnamed: 8                     0 non-null      float64
#  9   Unnamed: 9                     0 non-null      float64
#  10  Unnamed: 10                    0 non-null      float64
#  11  Estado                         18915 non-null  int64
#  12  FechaAltaSolicitud             18915 non-null  object
#  13  NumeroClub                     18915 non-null  object
#  14  DescripcionEntidad             18915 non-null  object
#  15  Temporada                      18915 non-null  int64
#  16  Modalidad                      18915 non-null  object
#  17  Categoria                      18915 non-null  object
#  18  Complementos                   5080 non-null   object
#  19  ImporteComplemento             18915 non-null  int64
#  20  ImporteFMM                     18915 non-null  float64
#  21  ImporteSeguro                  18915 non-null  float64
#  22  ImporteFederacionEsp           18915 non-null  float64
#  23  ImporteDescuento               18915 non-null  int64
#  24  ImporteAmpliacion              18915 non-null  float64
#  25  Cuota_Socio                    18915 non-null  int64
#  26  Relacion                       18915 non-null  int64
#  27  NSocio                         18915 non-null  int64
#  28  DireccionDomicilio             18915 non-null  object
#  29  NIFFamiliar                    554 non-null    object
#  30  TipoTarjeta                    18915 non-null  object
#  31  Alta                           18915 non-null  object
#  32  Cuaderno19                     18915 non-null  object
#  33  Bloqueado envíos               18915 non-null  object
#  34  Unnamed: 34                    0 non-null      float64
#  35  Envío tarjeta                  18915 non-null  object
#  36  Discapacidad                   18915 non-null  object
# dtypes: float64(8), int64(7), object(22)
# memory usage: 5.3+ MB

# %%
df_fer_2024_arrate.columns
# Out:
# Index(['Nombre', 'Apellido1', 'Apellido2', 'Sexo', 'FechaNacimiento',
#        'PoblacionDomicilio', 'DescripcionProvinciaDomicilio',
#        'CodigoPostalDomicilio', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Estado', 'FechaAltaSolicitud', 'NumeroClub', 'DescripcionEntidad',
#        'Temporada', 'Modalidad', 'Categoria', 'Complementos',
#        'ImporteComplemento', 'ImporteFMM', 'ImporteSeguro',
#        'ImporteFederacionEsp', 'ImporteDescuento', 'ImporteAmpliacion',
#        'Cuota_Socio', 'Relacion', 'NSocio', 'DireccionDomicilio',
#        'NIFFamiliar', 'TipoTarjeta', 'Alta', 'Cuaderno19', 'Bloqueado envíos',
#        'Unnamed: 34', 'Envío tarjeta', 'Discapacidad'],
#       dtype='object')

# %% [markdown]
# columnas a borrar: 'Sexo', 'FechaAltaSolicitud', 'Temporada',  'Complementos',
#        'ImporteComplemento', 'ImporteFMM', 'ImporteSeguro',
#        'ImporteFederacionEsp', 'ImporteDescuento', 'ImporteAmpliacion', 'Cuota_Socio', 'NIFFamiliar',
#        'Cuaderno19', 'Bloqueado envíos'

# %%
# A borrar ahora: ["Unnamed: 8","Unnamed: 9","Unnamed: 10","Complementos","NIFFamiliar","Unnamed: 34",'Cuaderno19', 'Bloqueado envíos'].

df_fer_2024_arrate = df_fer_2024_arrate.drop(["Unnamed: 8","Unnamed: 9","Unnamed: 10","Unnamed: 34",'Sexo', 'FechaAltaSolicitud', 'Temporada',  'Complementos',
       'ImporteComplemento', 'ImporteFMM', 'ImporteSeguro',
       'ImporteFederacionEsp', 'ImporteDescuento', 'ImporteAmpliacion', 'Cuota_Socio', 'NIFFamiliar',
       'Cuaderno19', 'Bloqueado envíos'], axis=1)
df_fer_2024_arrate.columns = df_fer_2024_arrate.columns.str.lower()

df_fer_2024_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18915 entries, 0 to 18914
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   nombre                         18915 non-null  object
#  1   apellido1                      18915 non-null  object
#  2   apellido2                      18896 non-null  object
#  3   fechanacimiento                18915 non-null  object
#  4   poblaciondomicilio             18915 non-null  object
#  5   descripcionprovinciadomicilio  18915 non-null  object
#  6   codigopostaldomicilio          18915 non-null  object
#  7   estado                         18915 non-null  int64
#  8   numeroclub                     18915 non-null  object
#  9   descripcionentidad             18915 non-null  object
#  10  modalidad                      18915 non-null  object
#  11  categoria                      18915 non-null  object
#  12  relacion                       18915 non-null  int64
#  13  nsocio                         18915 non-null  int64
#  14  direcciondomicilio             18915 non-null  object
#  15  tipotarjeta                    18915 non-null  object
#  16  alta                           18915 non-null  object
#  17  envío tarjeta                  18915 non-null  object
#  18  discapacidad                   18915 non-null  object
# dtypes: int64(3), object(16)
# memory usage: 2.7+ MB

# %%
# Creamos variable edad y borrar "fechanacimiento"
df_fer_2024_arrate["fechanacimiento"] = pd.to_datetime(df_fer_2024_arrate["fechanacimiento"])
df_fer_2024_arrate["edad"] = 2024 - df_fer_2024_arrate["fechanacimiento"].dt.year
df_fer_2024_arrate = df_fer_2024_arrate.drop("fechanacimiento", axis=1)
df_fer_2024_arrate.columns
# Out:
# Index(['nombre', 'apellido1', 'apellido2', 'poblaciondomicilio',
#        'descripcionprovinciadomicilio', 'codigopostaldomicilio', 'estado',
#        'numeroclub', 'descripcionentidad', 'modalidad', 'categoria',
#        'relacion', 'nsocio', 'direcciondomicilio', 'tipotarjeta', 'alta',
#        'envío tarjeta', 'discapacidad', 'edad'],
#       dtype='object')

# %%
# Crear columna federadado_2024
df_fer_2024_arrate['federado_2024'] = df_fer_2024_arrate['nombre'].notna()

# %%
df_fer_2024_arrate.head(5)
# Out:
#             nombre apellido1  apellido2 poblaciondomicilio  \
# 0     MIGUEL ANGEL      ABAD       ABAD        GUADALAJARA
# 1         CRISTINA      ABAD     ARRANZ         VALLADOLID
# 2             LUNA      ABAD     CAMPOS             GETAFE
# 3     JOSE ANTONIO      ABAD    CANDELA             MADRID
# 4  ESTEBAN EUSEBIO      ABAD  DE MIGUEL             MADRID
#
#   descripcionprovinciadomicilio codigopostaldomicilio  estado numeroclub  \
# 0                   GUADALAJARA                 19003       3  07.28.000
# 1                    VALLADOLID                 47300       3  07.28.370
# 2                        MADRID                 28906       3  07.28.000
# 3                        MADRID                 28028       3  07.28.000
# 4                        MADRID                 28017       3  07.28.000
#
#   descripcionentidad modalidad       categoria  relacion  nsocio  \
# 0     FMM INDIVIDUAL         C     Mayor Varón      8592   77005
# 1   CDE TODOVERTICAL         B     Mayor Mujer      3660   71299
# 2     FMM INDIVIDUAL        AU  Infantil Mujer       263   73846
# 3     FMM INDIVIDUAL        AU     Mayor Varón       182   58372
# 4         INDIVIDUAL         A     Mayor Varón      3052   56522
#
#                             direcciondomicilio tipotarjeta        alta  \
# 0                     CALLE CONSTITUCIÓN 37 4D           D        FORM
# 1              CARRETERA DE PESQUERA NUMERO 30           D     SERVWEB
# 2  CALLE DE LA GIGANTA ANDANDONA 6 PORTAL 1 3C           P  INDIVIDUAL
# 3       AVENIDA BAVIERA NUMERO 12 PISO 6º, IZQ           P  INDIVIDUAL
# 4             CALLE SERVANDO BATANERO NUMERO 1           D      ENLACE
#
#   envío tarjeta discapacidad  edad  federado_2024
# 0            NO           NO    31           True
# 1            NO           NO    34           True
# 2            NO           NO    11           True
# 3            NO           NO    88           True
# 4            NO           NO    78           True

# %%
# Renombrar algunas de las columnas _2024 (especificando el año) de cara a la unión de los dataset.

columnas = ['estado', 'numeroclub', 'descripcionentidad',
       'modalidad', 'cuota_socio', 'relacion',
       'tipotarjeta', 'alta', 'envío tarjeta',
       'edad']
df_fer_2024_arrate.rename(columns={col: col + "_2024" for col in columnas}, inplace=True)
df_fer_2024_arrate.columns
# Out:
# Index(['nombre', 'apellido1', 'apellido2', 'poblaciondomicilio',
#        'descripcionprovinciadomicilio', 'codigopostaldomicilio', 'estado_2024',
#        'numeroclub_2024', 'descripcionentidad_2024', 'modalidad_2024',
#        'categoria', 'relacion_2024', 'nsocio', 'direcciondomicilio',
#        'tipotarjeta_2024', 'alta_2024', 'envío tarjeta_2024', 'discapacidad',
#        'edad_2024', 'federado_2024'],
#       dtype='object')

# %%
# Borramos duplicados basados en 'nombre','apellido1','apellido2','poblaciondomicilio'
df_fer_2024_arrate.drop_duplicates(subset=['nombre','apellido1','apellido2','poblaciondomicilio'], keep='first', inplace=True)

# %%
df_fer_2024_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18898 entries, 0 to 18914
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   nombre                         18898 non-null  object
#  1   apellido1                      18898 non-null  object
#  2   apellido2                      18879 non-null  object
#  3   poblaciondomicilio             18898 non-null  object
#  4   descripcionprovinciadomicilio  18898 non-null  object
#  5   codigopostaldomicilio          18898 non-null  object
#  6   estado_2024                    18898 non-null  int64
#  7   numeroclub_2024                18898 non-null  object
#  8   descripcionentidad_2024        18898 non-null  object
#  9   modalidad_2024                 18898 non-null  object
#  10  categoria                      18898 non-null  object
#  11  relacion_2024                  18898 non-null  int64
#  12  nsocio                         18898 non-null  int64
#  13  direcciondomicilio             18898 non-null  object
#  14  tipotarjeta_2024               18898 non-null  object
#  15  alta_2024                      18898 non-null  object
#  16  envío tarjeta_2024             18898 non-null  object
#  17  discapacidad                   18898 non-null  object
#  18  edad_2024                      18898 non-null  int32
#  19  federado_2024                  18898 non-null  bool
# dtypes: bool(1), int32(1), int64(3), object(15)
# memory usage: 2.8+ MB

# %% [markdown]
#  Columnas a cambiar: categoría (Niña, niño, mujer, hombre), discapacidad (si, no)

# %% [markdown]
# # Licencias 2025

# %%
df_fer_2025_arrate = pd.read_csv("/Users/Arrate/Desktop/Licencias_2025.csv")

df_fer_2025_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18251 entries, 0 to 18250
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   NIF                            18251 non-null  object
#  1   Nombre                         18251 non-null  object
#  2   Apellido1                      18251 non-null  object
#  3   Apellido2                      18233 non-null  object
#  4   Sexo                           18251 non-null  object
#  5   FechaNacimiento                18251 non-null  object
#  6   PoblacionDomicilio             18251 non-null  object
#  7   DescripcionProvinciaDomicilio  18251 non-null  object
#  8   CodigoPostalDomicilio          18251 non-null  int64
#  9   Telefono1                      18251 non-null  int64
#  10  Telefono2                      4667 non-null   object
#  11  Email                          18247 non-null  object
#  12  Estado                         18251 non-null  int64
#  13  FechaAltaSolicitud             18251 non-null  object
#  14  NumeroClub                     18251 non-null  object
#  15  DescripcionEntidad             18251 non-null  object
#  16  Temporada                      18251 non-null  int64
#  17  Modalidad                      18251 non-null  object
#  18  Categoria                      18251 non-null  object
#  19  Complementos                   4803 non-null   object
#  20  ImporteComplemento             18251 non-null  int64
#  21  ImporteFMM                     18251 non-null  float64
#  22  ImporteSeguro                  18251 non-null  float64
#  23  ImporteFederacionEsp           18251 non-null  float64
#  24  ImporteDescuento               18251 non-null  int64
#  25  ImporteAmpliacion              18251 non-null  float64
#  26  Cuota_Socio                    18251 non-null  int64
#  27  Relacion                       18251 non-null  int64
#  28  NSocio                         18251 non-null  int64
#  29  DireccionDomicilio             18251 non-null  object
#  30  NIFFamiliar                    509 non-null    object
#  31  TipoTarjeta                    18251 non-null  object
#  32  Alta                           18251 non-null  object
#  33  Cuaderno19                     18251 non-null  object
#  34  Bloqueado envíos               18251 non-null  object
#  35  NCuentaBancaria                7622 non-null   object
#  36  Acceso formulario              18251 non-null  object
#  37  Envío tarjeta                  18251 non-null  object
#  38  Discapacidad                   18251 non-null  object
# dtypes: float64(4), int64(9), object(26)
# memory usage: 5.4+ MB

# %%
df_fer_2025_arrate.head(5)
# Out:
#          NIF      Nombre Apellido1  Apellido2 Sexo FechaNacimiento  \
# 0  51451495N     BEATRIZ      ABAD   CARRILLO    M       3/11/1986
# 1  05305866L     EDUARDO      ABAD       DIAZ    H      10/24/1990
# 2  52479225X       AARON      ABAD    ESTEBAN    H       1/26/1981
# 3  50725543D       JAIME      ABAD    ESTEBAN    H       4/12/1972
# 4  00671764A  CONCEPCION      ABAD  FERNANDEZ    M       6/19/1957
#
#   PoblacionDomicilio DescripcionProvinciaDomicilio  CodigoPostalDomicilio  \
# 0             MADRID                        MADRID                  28039
# 1             MADRID                        MADRID                  28010
# 2          LAS ROZAS                        MADRID                  28290
# 3             MADRID                        MADRID                  28002
# 4             MADRID                        MADRID                  28029
#
#    Telefono1  ...                           DireccionDomicilio NIFFamiliar  \
# 0  615274289  ...         CALLE LORENZA CORREA 23 3 DRCHA IZDA         NaN
# 1  679906030  ...                  C/ ALONSO CANO Nº 15 BAJO A         NaN
# 2  630700068  ...                     CALLE AMPURIAS NUMERO 12         NaN
# 3  629630182  ...  Calle PADRE CLARET Numero 11 Piso 5 Letra A         NaN
# 4  651758322  ...                      CALLE VILLA DE MARIN 28         NaN
#
#    TipoTarjeta        Alta Cuaderno19 Bloqueado envíos  \
# 0            D      ENLACE         NO               NO
# 1            P  INDIVIDUAL         SI               NO
# 2            D      REMESA         SI               NO
# 3            P  INDIVIDUAL         SI               NO
# 4            P     SERVWEB         NO               NO
#
#             NCuentaBancaria  \
# 0                       NaN
# 1  ES2814650200211719279500
# 2  ES4300810469410001005211
# 3  ES8700730100560407453503
# 4                       NaN
#
#                                    Acceso formulario Envío tarjeta  \
# 0  https://fmmlicencias.com/FMM/AccesoFederado.as...            NO
# 1  https://fmmlicencias.com/FMM/AccesoFederado.as...            NO
# 2  https://fmmlicencias.com/FMM/AccesoFederado.as...            NO
# 3  https://fmmlicencias.com/FMM/AccesoFederado.as...            NO
# 4  https://fmmlicencias.com/FMM/AccesoFederado.as...            NO
#
#   Discapacidad
# 0           NO
# 1           NO
# 2           NO
# 3           NO
# 4           NO
#
# [5 rows x 39 columns]

# %%
# Borrar las mismas columnas que en licencias 2024 + especificas de 2025
df_fer_2025_arrate = df_fer_2025_arrate.drop(['Sexo', 'FechaAltaSolicitud', 'Temporada',  'Complementos',
       'ImporteComplemento', 'ImporteFMM', 'ImporteSeguro',
       'ImporteFederacionEsp', 'ImporteDescuento', 'ImporteAmpliacion',
       'Cuota_Socio', 'NIFFamiliar',
       'Cuaderno19', 'Bloqueado envíos','Telefono1',
       'Email',"NIFFamiliar", 'NCuentaBancaria', 'Telefono2', 'Acceso formulario'], axis=1)
df_fer_2025_arrate.columns = df_fer_2025_arrate.columns.str.lower()

# Creamos variable edad y borrar "fechanacimiento"
df_fer_2025_arrate["fechanacimiento"] = pd.to_datetime(df_fer_2025_arrate["fechanacimiento"])
df_fer_2025_arrate["edad"] = 2025 - df_fer_2025_arrate["fechanacimiento"].dt.year
df_fer_2025_arrate = df_fer_2025_arrate.drop("fechanacimiento", axis=1)

# Crear columna federadado_2025
df_fer_2025_arrate['federado_2025'] = df_fer_2025_arrate['nombre'].notna()

# Renombrar algunas de las columnas _2025 (especificando el año) de cara a la unión de los dataset.

columnas = ['estado', 'numeroclub', 'descripcionentidad',
       'modalidad', 'relacion',
       'tipotarjeta', 'envío tarjeta', 'alta',
       'edad']
df_fer_2025_arrate.rename(columns={col: col + "_2025" for col in columnas}, inplace=True)

# %%
# Borramos duplicados basados en 'nombre','apellido1','apellido2','poblaciondomicilio'
df_fer_2025_arrate.drop_duplicates(subset=['nif','nombre','apellido1','apellido2','poblaciondomicilio'], keep='first', inplace=True)

# %%
df_fer_2025_arrate.columns
# Out:
# Index(['nif', 'nombre', 'apellido1', 'apellido2', 'poblaciondomicilio',
#        'descripcionprovinciadomicilio', 'codigopostaldomicilio', 'estado_2025',
#        'numeroclub_2025', 'descripcionentidad_2025', 'modalidad_2025',
#        'categoria', 'relacion_2025', 'nsocio', 'direcciondomicilio',
#        'tipotarjeta_2025', 'alta_2025', 'envío tarjeta_2025', 'discapacidad',
#        'edad_2025', 'federado_2025'],
#       dtype='object')

# %%
df_fer_2025_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18249 entries, 0 to 18250
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   nif                            18249 non-null  object
#  1   nombre                         18249 non-null  object
#  2   apellido1                      18249 non-null  object
#  3   apellido2                      18231 non-null  object
#  4   poblaciondomicilio             18249 non-null  object
#  5   descripcionprovinciadomicilio  18249 non-null  object
#  6   codigopostaldomicilio          18249 non-null  int64
#  7   estado_2025                    18249 non-null  int64
#  8   numeroclub_2025                18249 non-null  object
#  9   descripcionentidad_2025        18249 non-null  object
#  10  modalidad_2025                 18249 non-null  object
#  11  categoria                      18249 non-null  object
#  12  relacion_2025                  18249 non-null  int64
#  13  nsocio                         18249 non-null  int64
#  14  direcciondomicilio             18249 non-null  object
#  15  tipotarjeta_2025               18249 non-null  object
#  16  alta_2025                      18249 non-null  object
#  17  envío tarjeta_2025             18249 non-null  object
#  18  discapacidad                   18249 non-null  object
#  19  edad_2025                      18249 non-null  int32
#  20  federado_2025                  18249 non-null  bool
# dtypes: bool(1), int32(1), int64(4), object(15)
# memory usage: 2.9+ MB

# %%
# Unión de los df de licencias 2024 + 2025
# .merge() --- how='outer' 
# conserva todas las filas de ambos dataframes, y las columnas comunes aparecen una sola vez.

columnas_comunes = list(set(df_fer_2024_arrate.columns) & set(df_fer_2025_arrate.columns))
df_federados = df_fer_2024_arrate.merge(df_fer_2025_arrate, on=columnas_comunes, how='outer')

# %%
df_federados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27208 entries, 0 to 27207
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   nombre                         27208 non-null  object
#  1   apellido1                      27208 non-null  object
#  2   apellido2                      27175 non-null  object
#  3   poblaciondomicilio             27208 non-null  object
#  4   descripcionprovinciadomicilio  27208 non-null  object
#  5   codigopostaldomicilio          27208 non-null  object
#  6   estado_2024                    18898 non-null  float64
#  7   numeroclub_2024                18898 non-null  object
#  8   descripcionentidad_2024        18898 non-null  object
#  9   modalidad_2024                 18898 non-null  object
#  10  categoria                      27208 non-null  object
#  11  relacion_2024                  18898 non-null  float64
#  12  nsocio                         27208 non-null  int64
#  13  direcciondomicilio             27208 non-null  object
#  14  tipotarjeta_2024               18898 non-null  object
#  15  alta_2024                      18898 non-null  object
#  16  envío tarjeta_2024             18898 non-null  object
#  17  discapacidad                   27208 non-null  object
#  18  edad_2024                      18898 non-null  float64
#  19  federado_2024                  18898 non-null  object
#  20  nif                            18249 non-null  object
#  21  estado_2025                    18249 non-null  float64
#  22  numeroclub_2025                18249 non-null  object
#  23  descripcionentidad_2025        18249 non-null  object
#  24  modalidad_2025                 18249 non-null  object
#  25  relacion_2025                  18249 non-null  float64
#  26  tipotarjeta_2025               18249 non-null  object
#  27  alta_2025                      18249 non-null  object
#  28  envío tarjeta_2025             18249 non-null  object
#  29  edad_2025                      18249 non-null  float64
#  30  federado_2025                  18249 non-null  object
# dtypes: float64(6), int64(1), object(24)
# memory usage: 6.4+ MB

# %%
df_federados.head()
# Out:
#           nombre apellido1 apellido2 poblaciondomicilio  \
# 0         MIGUEL      VELA  BATANERO              19001
# 1       CAROLINA   REDONDO     CALVO                 28
# 2  MARIA DOLORES    CRESPO    HERVAS              28002
# 3       ANGELICA      SANZ       ULL              28002
# 4         MIGUEL     ARNES     GOMEZ              28033
#
#   descripcionprovinciadomicilio codigopostaldomicilio  estado_2024  \
# 0                   GUADALAJARA                 19001          3.0
# 1                        MADRID                 28224          3.0
# 2                        MADRID                 28002          3.0
# 3                        MADRID                 28002          3.0
# 4                        MADRID                 28033          3.0
#
#   numeroclub_2024                descripcionentidad_2024 modalidad_2024  ...  \
# 0       07.28.000                         FMM INDIVIDUAL             B6  ...
# 1       07.28.010           C. ALPINO PIEDRAFITA-POZUELO              B  ...
# 2       07.28.455  C.D.E. PURA VIDA MONTAÑA Y NATURALEZA              B  ...
# 3       07.28.000                         FMM INDIVIDUAL              B  ...
# 4       07.28.000                         FMM INDIVIDUAL              B  ...
#
#   estado_2025  numeroclub_2025  descripcionentidad_2025 modalidad_2025  \
# 0         NaN              NaN                      NaN            NaN
# 1         NaN              NaN                      NaN            NaN
# 2         NaN              NaN                      NaN            NaN
# 3         NaN              NaN                      NaN            NaN
# 4         NaN              NaN                      NaN            NaN
#
#   relacion_2025 tipotarjeta_2025 alta_2025 envío tarjeta_2025  edad_2025  \
# 0           NaN              NaN       NaN                NaN        NaN
# 1           NaN              NaN       NaN                NaN        NaN
# 2           NaN              NaN       NaN                NaN        NaN
# 3           NaN              NaN       NaN                NaN        NaN
# 4           NaN              NaN       NaN                NaN        NaN
#
#   federado_2025
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# # Licencias 2023

# %%
df_fer_2023_arrate = pd.read_csv("/Users/Arrate/Desktop/2023.xlsx - 2023.csv")

df_fer_2023_arrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19489 entries, 0 to 19488
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   NIF                            19489 non-null  object
#  1   Nombre                         19489 non-null  object
#  2   Apellido1                      19489 non-null  object
#  3   Apellido2                      19478 non-null  object
#  4   Sexo                           19489 non-null  object
#  5   FechaNacimiento                19489 non-null  object
#  6   PoblacionDomicilio             19489 non-null  object
#  7   DescripcionProvinciaDomicilio  19489 non-null  object
#  8   CodigoPostalDomicilio          19489 non-null  object
#  9   Telefono1                      19471 non-null  object
#  10  Telefono2                      5363 non-null   object
#  11  Email                          19480 non-null  object
#  12  Estado                         19489 non-null  int64
#  13  FechaAltaSolicitud             19489 non-null  object
#  14  NumeroClub                     19489 non-null  object
#  15  DescripcionEntidad             19489 non-null  object
#  16  Temporada                      19489 non-null  int64
#  17  Modalidad                      19489 non-null  object
#  18  Categoria                      19489 non-null  object
#  19  Complementos                   5654 non-null   object
#  20  ImporteComplemento             19489 non-null  int64
#  21  ImporteFMM                     19489 non-null  float64
#  22  ImporteSeguro                  19489 non-null  float64
#  23  ImporteFederacionEsp           19489 non-null  int64
#  24  ImporteDescuento               19489 non-null  int64
#  25  ImporteAmpliacion              19489 non-null  int64
#  26  Cuota_Socio                    19489 non-null  int64
#  27  Relacion                       19489 non-null  int64
#  28  NSocio                         19489 non-null  int64
#  29  DireccionDomicilio             19489 non-null  object
#  30  NIFFamiliar                    561 non-null    object
#  31  TipoTarjeta                    19489 non-null  object
#  32  Alta                           19489 non-null  object
#  33  Cuaderno19                     19489 non-null  object
#  34  Bloqueado envíos               19489 non-null  object
#  35  NCuentaBancaria                8661 non-null   object
#  36  Acceso formulario              19489 non-null  object
#  37  Envío tarjeta                  19489 non-null  object
#  38  Discapacidad                   19489 non-null  object
# dtypes: float64(2), int64(9), object(28)
# memory usage: 5.8+ MB
# C:\Users\Arrate\AppData\Local\Temp\ipykernel_3904\3567124890.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fer_2023_arrate = pd.read_csv("/Users/Arrate/Desktop/2023.xlsx - 2023.csv")

# %%
# Borrar las mismas columnas que en licencias 2024 y 2025 + especificas de 2023
df_fer_2023_arrate = df_fer_2023_arrate.drop(['Telefono1','FechaAltaSolicitud', 'Email',"Complementos","NIFFamiliar",'Cuaderno19', 'Bloqueado envíos', 'NCuentaBancaria', 'Temporada', 'Telefono2', 'Acceso formulario'], axis=1)
df_fer_2023_arrate.columns = df_fer_2023_arrate.columns.str.lower()

# Creamos variable edad y borrar "fechanacimiento"
df_fer_2023_arrate["fechanacimiento"] = pd.to_datetime(df_fer_2023_arrate["fechanacimiento"])
df_fer_2023_arrate["edad"] = 2023 - df_fer_2023_arrate["fechanacimiento"].dt.year
df_fer_2023_arrate = df_fer_2023_arrate.drop("fechanacimiento", axis=1)

# Crear columna federadado_2025
df_fer_2023_arrate['federado_2023'] = df_fer_2023_arrate['nombre'].notna()

# Renombrar algunas de las columnas _2023 (especificando el año) de cara a la unión de los dataset.

columnas = ['estado', 'numeroclub', 'descripcionentidad',
       'modalidad', 'importecomplemento', 'importefmm',
       'importeseguro', 'importefederacionesp', 'importedescuento',
       'importeampliacion', 'cuota_socio', 'relacion',
       'tipotarjeta', 'envío tarjeta', 'alta',
       'edad']
df_fer_2023_arrate.rename(columns={col: col + "_2023" for col in columnas}, inplace=True)
